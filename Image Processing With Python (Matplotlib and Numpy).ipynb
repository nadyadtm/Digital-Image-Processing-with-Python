# %% [markdown]
# # Image Processing with Python (Dengan Matplotlib dan Numpy)
# Halo Netizen yang budiman
# Daripada gabut mikirin mantan yuk mending belajar image processing pake python. Dijamin gabutnya berfaedah

# %% [markdown]
# ## Jadi kita tuh ngapain aja ya?
# Nah kita belajar image processingnya pake numpy sama matplotlib yaa. Sudah terinstall kok kalau kamu pake anaconda hehe. Oke kita mulai.

# %% [markdown]
# Pertama-tama kita import dulu matplotlib sama numpynya. Jangan lupa menggunakan ".pylab as plt" yaa

# %%
import matplotlib.pylab as plt
import matplotlib.image as mpimg
import numpy
import scipy

# %% [markdown]
# Kalau sudah import kita load image disini, caranya adalah menggunakan perintah imread untuk membaca gambar, dan imshow untuk menampilkan gambar

# %%
img = plt.imread('lena.jpg')
plt.imshow(img)
plt.imsave('lena.png',img)

# %% [markdown]
# Selamat! kamu sudah bisa melakukan load gambar dan menampilkannya dalam notebook ini. Selanjutnya mari kita mulai sedikit operasi citra

# %% [markdown]
# ### Grayscale Picture
# Baiklah mari kita coba mengubah citra menjadi abu-abu. Disini kita menggunakan rumus sebagai berikut
#
# #### Hasil = aR + bG + cB, dimana a+b+c=1
# Sedangkan R, G, B merupakan matriksnya
#
# Okay, lets begin

# %%
xx = img.astype(numpy.uint8)
type(xx)
#gray = 0.6 * xx[:,:,0] + 0.2 * xx[:,:,1] + 0.2 * xx[:,:,2]
#plt.imshow(gray)
# Out:
# numpy.ndarray

# %% [markdown]
# Oke kamu sudah bisa mengubah citra menjadi abu-abu. Mungkin ini hasil di laptop aku seperti ini gak tau yaa kalau di laptop kalian haha

# %% [markdown]
# ### Negative Picture
# Nah habis itu kita coba mengubah gambar jadi negatif yaa
#
# Caranya adalah mengurangkan citra dengan 255.
# Let's do this

# %%
neg = 255 - img
plt.imshow(neg)

# %% [markdown]
# ### Brightness
# Next is brightness. Caranya cukup sangat mudah. Ada dua cara
# 1. Penerangan tambah
# 2. Penerangan kali
#
# Dua-duanya punya perbandingan. Kalau menurut aku penerangan tambah itu hasilnya lebih bagus dari penerangan kali karena penerangan kali jadi banyak noisenya dan terangnya tidak merata
#
# Okay, what are you waiting for? Lets go and try

# %%
pngtbh = img + 100
pngkl = img * 3

# %% [markdown]
# Lets check the differences, ini penerangan tambah

# %%
plt.imshow(pngtbh)

# %% [markdown]
# Kalau ini penerangan kali

# %%
plt.imshow(pngkl)
